# %%
import pandas as pd

# %%
df = pd.read_csv('https://archives.nseindia.com/content/indices/ind_close_all_31122021.csv')

# %%
df
# Out:
#                                    Index Name  Index Date Open Index Value  \
# 0                                    Nifty 50  31-12-2021          17244.5
# 1                               Nifty Next 50  31-12-2021         41641.05
# 2                                   Nifty 100  31-12-2021         17488.45
# 3                                   Nifty 200  31-12-2021           9145.8
# 4                                   Nifty 500  31-12-2021         14879.25
# ..                                        ...         ...              ...
# 88          Nifty 15 yr and above G-Sec Index  31-12-2021          2697.54
# 89                Nifty Composite G-sec Index  31-12-2021          2362.84
# 90                Nifty 10 yr Benchmark G-Sec  31-12-2021          2055.52
# 91  Nifty 10 yr Benchmark G-Sec (Clean Price)  31-12-2021           921.66
# 92                        Nifty 1D Rate Index  31-12-2021                -
#
# ...

# %%
df1 = pd.read_csv('https://www1.nseindia.com/content/nsccl/AUB_2021246_31122021.csv')
df1.info()
#df1.sort_values(by=['Total Qty'], inplace=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 286 entries, ('Sr No', 'Symbol', 'Series') to ('285', 'ZOMATO', 'EQ')
# Data columns (total 1 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   Confirmed list of securities to be auctioned in A 2021246 to be held on Dec 31 2021.  286 non-null    object
# dtypes: object(1)
# memory usage: 28.2+ KB
